# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus2010ney-star/atividades-python/blob/main/atividade_01python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Atividade 01 — Introdução ao Python

# %%
print("Olá mundo!")
print("Curso Técnico em Informática")
# Out:
# Olá mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: ALP
# Digite o conteúdo estudado: Python
# Digite o número da atividade: 01
#
# --- Informações da atividade ---
# Disciplina: ALP
# Conteúdo: Python
# Atividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado: ", soma)
# Out:
# Resultado:  30

# %%
print("Aprendendo versionamento de projetos!")
# Out:
# Aprendendo versionamento de projetos!
